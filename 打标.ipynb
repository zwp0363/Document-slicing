# %%
import re
import time
import json
from pymongo import MongoClient
import dashscope
from http import HTTPStatus

# %%
# ================= 配置区域 =================

# 1. 请在此处填入您的阿里千问 API Key
dashscope.api_key = 'sk-fa13f585000140deabdfa506b25a7f3d' 

# 2. 数据库配置
MONGO_URI = 'mongodb://admin:12345678@192.168.16.138:27017/?authSource=admin'
DB_NAME = "test"
COLLECTION_NAME = "overseas_website_data_all"

# ===========================================

# %%
# --- 数据库连接 ---
client = MongoClient(MONGO_URI)
db = client[DB_NAME]
source_collection = db[COLLECTION_NAME]

# %%
# --- 中国相关性筛选 (保持原逻辑) ---
CHINA_KEYWORDS = [
    "China", "Chinese", "Beijing", "PRC", "People's Republic of China", "Mainland China", 
    "State Council", "Zhongnanhai", "CCP", "Communist Party of China", "Xi Jinping", 
    "Politburo", "Yuan", "RMB", "Renminbi", "Belt and Road", "BRI", "Made in China", 
    "Huawei", "Tencent", "Alibaba", "ByteDance", "TikTok", "PLA", "People's Liberation Army", 
    "Shanghai", "Shenzhen", "Hong Kong", "Macau", "Macao", "Taiwan", "Taipei", 
    "Xinjiang", "Tibet", "South China Sea", "Sino-"
]
CHINA_KEYWORD_REGEX = [re.compile(r'\bsino-', re.IGNORECASE)] + [
    re.compile(r'\b' + re.escape(kw.lower()) + r'\b', re.IGNORECASE) for kw in CHINA_KEYWORDS if kw != "Sino-"
]

# %%
# --- 新增：战略资源领域的详细三级关键词定义 ---
# 结构：Category -> { 'base_keywords': [旧的粗略匹配词], 'detailed_tags': { 三级分类: [详细词表] } }
# 这里的 Key (稀土, 矿产, 能源) 即为【二级标签】
# 它们统一属于【一级标签：战略资源】
STRATEGIC_RESOURCES_CONFIG = {
    "稀土": {
        # 旧模式
        "base_keywords": ["rare earth", "rare earth elements", "REE", "rare earth metals", "Light Rare Earth Elements", "LREE", "lanthanum", "La", "cerium", "Ce", "praseodymium", "Pr", "neodymium", "Nd", "promethium", "Pm", "samarium", "Sm", "europium", "Eu", "Heavy Rare Earth Elements", "HREE", "scandium", "Sc", "gadolinium", "Gd", "terbium", "Tb", "dysprosium", "Dy", "holmium", "Ho", "erbium", "Er", "thulium", "Tm", "ytterbium", "Yb", "lutetium", "Lu", "yttrium", "Permanent Magnets", "rare earth magnet", "NdFeB", "neodymium iron boron", "SmCo", "samarium cobalt", "Mining Technology", "rare earth mining", "extraction technology", "Separation & Purification", "rare earth separation", "purification process", "solvent extraction", "rare earth recycling", "rare earth production"], 
        "detailed_tags": {
            "轻稀土": ["Light Rare Earth Elements", "LREE", "Lanthanum", "La", "Cerium", "Ce", "Praseodymium", "Pr", "Neodymium", "Nd", "Promethium", "Pm", "Samarium", "Sm", "Europium", "Eu"],
            "重稀土": ["Heavy Rare Earth Elements", "HREE", "Gadolinium", "Gd", "Terbium", "Tb", "Dysprosium", "Dy", "Holmium", "Ho", "Erbium", "Er", "Thulium", "Tm", "Ytterbium", "Yb", "Lutetium", "Lu", "Yttrium", "Y", "Scandium", "Sc"],
            "永磁材料": ["Permanent Magnets", "NdFeB", "Neodymium Iron Boron", "SmCo", "Samarium Cobalt", "rare earth magnet"],
            "开采与分离技术": ["Mining Technology", "extraction technology", "Separation & Purification", "rare earth separation", "purification process", "solvent extraction"],
            "回收利用": ["Recycling", "rare earth recycling", "urban mining"]
        }
    },
    "矿产": {
        # 旧模式
        "base_keywords": ["mineral", "minerals", "critical minerals", "strategic minerals", "mineral resources", "mining", "Mining technology", "Energy Minerals", "uranium", "U", "thorium", "Th", "Metallic Minerals", "lithium", "Li", "cobalt", "Co", "nickel", "Ni", "copper", "Cu", "tungsten", "W", "tin", "Sn", "antimony", "Sb", "beryllium", "Be", "niobium", "Nb", "tantalum", "Ta", "zirconium", "Zr", "Non-metallic Minerals", "Fluorite", "Graphite", "Quartz"],
        "detailed_tags": {
            "能源矿产": ["Energy Minerals", "Uranium", "U", "Thorium", "Th"], # 建议实际使用全称，单字母容易误判，此处已补全
            "金属矿产": [
                "Metallic Minerals", 
                "Lithium", "Li", "Cobalt", "Co", "Nickel", "Ni", 
                "Tungsten", "W", "Tin", "Sn", "Antimony", "Sb", 
                "Beryllium", "Be", "Niobium", "Nb", "Tantalum", "Ta", "Zirconium", "Zr"
            ],
            "非金属矿产": ["Non-metallic Minerals", "Fluorite", "Graphite", "Quartz"],
            "采矿技术": ["Mining technology", "deep sea mining", "open-pit mining"]
        }
    },
    "能源": {
        # 旧模式
        "base_keywords": ["energy", "energy resources", "oil", "natural gas", "petroleum", "LNG", "liquefied natural gas", "coal", "uranium", "nuclear energy", "energy security", "Tradition Energy", "New Energy", "Renewables", "renewable energy", "Hydrogen Energy", "Solar Power", "Nuclear Power", "Wind Power", "Energy Storage", "Energy Transport"],
        "detailed_tags": {
            "传统能源": ["Tradition Energy", "Petroleum", "Oil", "Coal", "Natural Gas", "LNG", "Fossil fuel"],
            "新能源": ["New Energy", "Renewables", "Renewable energy", "Hydrogen Energy", "Solar Power", "Photovoltaic", "Nuclear Power", "Wind Power", "Energy Storage", "Battery storage"],
            "能源运输": ["Energy Transport", "pipeline", "oil tanker", "LNG carrier", "energy grid", "transmission line"]
        }
    }
}

# %%
def extract_expanded_context(text, match_obj, max_chars=800):
    """
    提取 [前一句] + [当前句] + [后一句]
    """
    keyword_start = match_obj.start()
    keyword_end = match_obj.end()
    text_len = len(text)
    
    # 定义标点符号集合 (用于判断句子边界)
    punctuations = ['.', '?', '!']
    
    # --- 1. 寻找当前句子的边界 (Current Sentence) ---
    # 向前找句首
    curr_sent_start = 0
    for i in range(keyword_start, -1, -1):
        if text[i] in punctuations:
            # 只有当标点后面有空格或换行时，才视为句子结束，避免 "U.S." 误判
            # 这里做一个简单处理：找到标点就停，位置+1为句首
            curr_sent_start = i + 1
            break
            
    # 向后找句尾
    curr_sent_end = text_len
    for i in range(keyword_end, text_len):
        if text[i] in punctuations:
            curr_sent_end = i + 1
            break
            
    # --- 2. 寻找前一句的开始 (Previous Sentence) ---
    # 从当前句首的前一个字符开始，继续向前找标点
    prev_sent_start = 0 
    if curr_sent_start > 0:
        for i in range(curr_sent_start - 2, -1, -1):
            if text[i] in punctuations:
                prev_sent_start = i + 1
                break
    
    # --- 3. 寻找后一句的结束 (Next Sentence) ---
    # 从当前句尾的后一个字符开始，继续向后找标点
    next_sent_end = text_len
    if curr_sent_end < text_len:
        for i in range(curr_sent_end + 1, text_len):
            if text[i] in punctuations:
                next_sent_end = i + 1
                break
                
    # --- 4. 截取并清理 ---
    # 截取范围：[前一句首 : 后一句尾]
    expanded_text = text[prev_sent_start : next_sent_end].strip()
    
    # 安全限制：如果因为标点缺失导致提取内容过长，强制截断
    if len(expanded_text) > max_chars:
        # 回退到简单的窗口截取
        start = max(0, keyword_start - 300)
        end = min(text_len, keyword_end + 300)
        expanded_text = "..." + text[start:end] + "..."
        
    # 清理多余换行，保持整洁
    expanded_text = re.sub(r'\s+', ' ', expanded_text)
    
    return expanded_text

# %%
def verify_with_qwen(keyword, context, tag_name):
    """
    Prompt 升级：明确告知大模型这是三句话的上下文
    """
    prompt = f"""
    你是一个专业的战略资源情报分析师。
    
    【任务】
    判断提供的文本片段中，特定的“关键词”是否在语义上属于“目标分类”。
    
    【输入信息】
    1. 目标分类: "{tag_name}"
    2. 待分析关键词: "{keyword}"
    3. 文本片段 (包含关键词的前后句上下文): 
    "{context}"

    【判断逻辑】
    请阅读整个文本片段，分析该关键词的含义。
    - 如果关键词明确指代"{tag_name}"（例如 'Li' 指代锂元素，'Co' 指代钴矿），返回 true。
    - 如果关键词是缩写、人名的一部分、或其他普通单词（例如 'Co' 是 Co-operation, 'W' 是 George W. Bush），返回 false。
    - 如果语境完全无关，返回 false。

    【输出格式】
    请仅返回标准 JSON 字符串：
    {{
        "is_match": true,
        "reason": "请用一句话中文解释，例如：根据后文提到的电池生产，这里的Li指代锂资源。"
    }}
    """

    try:
        response = dashscope.Generation.call(
            model='qwen-turbo', # 使用 turbo 即可，速度快
            prompt=prompt,
            result_format='message',
        )

        if response.status_code == HTTPStatus.OK:
            content = response.output.choices[0].message.content
            # 清理 Markdown 代码块标记
            content = content.replace('```json', '').replace('```', '').strip()
            return content
        else:
            return f'{{"is_match": false, "reason": "API Error: {response.code}"}}'
            
    except Exception as e:
        return f'{{"is_match": false, "reason": "Exception: {str(e)}"}}'

# %%
def check_keywords_with_context(text, keywords):
    """
    检查文本中是否包含列表中的任意关键词，并提取上下文
    返回格式: [(keyword, context_string), ...]
    """
    found_items = []
    # 为了避免同一个词被多次记录（大小写差异），用 set 过滤一下
    seen_kws = set()

    for kw in keywords:
        if kw.lower() in seen_kws:
            continue
            
        # 针对单字母/双字母进行严格匹配及大小写控制
        if len(kw) <= 2:
             pattern = r'\b' + re.escape(kw) + r'\b'
             # 短词（如 U, W, Li）通常强制大小写敏感，避免误判
             # 如果您确定数据源非常杂乱，也可以改为 re.IGNORECASE，但风险很高
             match = re.search(pattern, text) 
        else:
            # 普通词忽略大小写匹配
            pattern = r'\b' + re.escape(kw.lower()) + r'\b'
            match = re.search(pattern, text, re.IGNORECASE)
            
        if match:
            context = extract_expanded_context(text, match)
            found_items.append((kw, context))
            seen_kws.add(kw.lower())
            
    return found_items

# %%
def test_strategic_resource_tagging():
    print("--- 开始测试：三级关键词匹配 + 前后句上下文 + AI 深度验证 ---\n")
    print("提示：系统将自动提取 [前一句 + 当前句 + 后一句] 发送给大模型进行分析。\n")
    print("注意：因为需要调用 API，处理速度会变慢，请耐心等待...\n")
    
    # 测试前 500 篇文档 
    cursor = source_collection.find({}, {"title": 1, "content": 1, "link": 1}).limit(500)
    
    total_processed = 0
    matched_docs = 0
    
    for doc in cursor:
        total_processed += 1
        content = doc.get("content", "")
        title = doc.get("title", "")
        link = doc.get("link", "")
        
        full_text = (str(title) + " " + str(content)).strip()
        if not full_text:
            continue

        # 1. 中国相关性
        is_china_related = False
        for regex in CHINA_KEYWORD_REGEX:
            if regex.search(full_text.lower()):
                is_china_related = True
                break
        
        # 2. 匹配逻辑
        doc_matches = {}
        has_match_in_doc = False

        # 遍历所有二级标签 (稀土, 矿产, 能源)
        for level_2_tag, config in STRATEGIC_RESOURCES_CONFIG.items():
            
            # A. 基础匹配 (原有的粗略匹配)
            base_hits_tuples = check_keywords_with_context(full_text, config["base_keywords"])
            
            # B. 详细三级匹配
            detailed_hits_info = {}
            has_detailed = False
            
            for level_3_tag, sub_keywords in config["detailed_tags"].items():
                hits_tuples = check_keywords_with_context(full_text, sub_keywords)
                if hits_tuples:
                    detailed_hits_info[level_3_tag] = hits_tuples
                    has_detailed = True
            
            # 只要命中基础词 OR 命中详细词，就记录下来
            if base_hits_tuples or has_detailed:
                doc_matches[level_2_tag] = {
                    "base": base_hits_tuples,
                    "detailed": detailed_hits_info
                }
                has_match_in_doc = True
        
        # 3. 打印结果
        if has_match_in_doc:
            matched_docs += 1
            print(f"[{total_processed}] 文档: {title[:60]}...")
            print(f"   Link: {link}")
            cn_status = "是" if is_china_related else "否"
            print(f"   [中国相关]: {cn_status}")
            
            # 打印一级标签
            print(f"   ★ 一级标签: 【战略资源】") # 此处固定为战略资源

            for level_2, data in doc_matches.items():
                base_tuples = data['base']
                detailed_dict = data['detailed']
                
                # 打印二级标签
                print(f"      ├── 二级标签: 【{level_2}】")
                
                # --- 部分 1: 原有关键词匹配 & AI 分析 ---
                if base_tuples:
                    print(f"      │     [原有关键词匹配 (Base) & AI 分析]:")
                    for kw, ctx in base_tuples:
                        print(f"      │           --------------------------------------------------")
                        print(f"      │           关键词: [{kw}]")
                        print(f"      │           上下文: \"{ctx}\"")
                        
                        # 注意：对于原有关键词，我们把“二级标签名”作为目标分类传给 AI
                        # 例如：判断 'rare earth' 是否属于 '稀土'
                        ai_result_json = verify_with_qwen(kw, ctx, level_2)
                        
                        try:
                            res = json.loads(ai_result_json)
                            is_match = res.get("is_match")
                            reason = res.get("reason")
                            icon = "✅" if is_match else "❌"
                            print(f"      │           {icon} AI 结论: {reason}")
                        except:
                            print(f"      │           ⚠️ AI JSON 解析失败: {ai_result_json}")
                        
                        time.sleep(0.3) # 避免 API 速率限制

                # --- 部分 2: 三级细分标签匹配 & AI 分析 ---
                if detailed_dict:
                    print(f"      │     [新增三级标签匹配 (Detailed) & AI 分析]:")
                    for level_3, hits in detailed_dict.items():
                        print(f"      │       + 三级分类: <{level_3}>")
                        for kw, ctx in hits:
                            print(f"      │           --------------------------------------------------")
                            print(f"      │           关键词: [{kw}]")
                            print(f"      │           上下文: \"{ctx}\"")
                            
                            # 这里传的是三级标签名，例如 '金属矿产'
                            ai_result_json = verify_with_qwen(kw, ctx, level_3)
                            
                            try:
                                res = json.loads(ai_result_json)
                                is_match = res.get("is_match")
                                reason = res.get("reason")
                                icon = "✅" if is_match else "❌"
                                print(f"      │           {icon} AI 结论: {reason}")
                            except:
                                print(f"      │           ⚠️ AI JSON 解析失败: {ai_result_json}")
                            
                            time.sleep(0.3) 
                
                if not base_tuples and not detailed_dict:
                    print("      │     (无匹配)")

                print("      │")
            print("=" * 90)

    print(f"\n测试结束。")
    print(f"共扫描文档: {total_processed}")
    print(f"命中【战略资源】相关文档: {matched_docs}")

# %%
if __name__ == "__main__":
    try:
        test_strategic_resource_tagging()
    except Exception as e:
        print(f"程序运行出错: {e}")
# Out:
# --- 开始测试：三级关键词匹配 + 前后句上下文 + AI 深度验证 ---
#
# 提示：系统将自动提取 [前一句 + 当前句 + 后一句] 发送给大模型进行分析。
#
# 注意：因为需要调用 API，处理速度会变慢，请耐心等待...
#
# [2] 文档: The low road to national insecurity: how state’s diplomacy f...
#    Link: https://www.aspi.org.au/strategist-posts/the-low-road-to-national-insecurity-how-states-diplomacy-fractures-australia/
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [Li]
#       │           上下文: "It creates a veneer of legitimacy for engagements that require the highest level of scrutiny. We have already seen the corrosive effect of programs such as the Confucius Institutes, which former senior Chinese Communist Party official Li Changchun described as ‘an important part of China’s overseas propaganda set-up’. These institutes have been linked to censorship of politically sensitive topics and have raised serious questions about academic freedom on Australian campuses."
#       │           ❌ AI 结论: 文本中提到的'Li'是人名，而非矿产相关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [Li]
#       │           上下文: "It creates a veneer of legitimacy for engagements that require the highest level of scrutiny. We have already seen the corrosive effect of programs such as the Confucius Institutes, which former senior Chinese Communist Party official Li Changchun described as ‘an important part of China’s overseas propaganda set-up’. These institutes have been linked to censorship of politically sensitive topics and have raised serious questions about academic freedom on Australian campuses."
#       │           ❌ AI 结论: 文本中提到的'Li'是人名，而非金属矿产。
#       │
# ==========================================================================================
# [4] 文档: When politics turns deadly: the case for a national resilien...
#    Link: https://www.aspi.org.au/strategist-posts/when-politics-turns-deadly-the-case-for-a-national-resilience-campaign/
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [Be]
#       │           上下文: "Australia has a proud history of national campaigns that build shared identity: the ‘Life. Be in it.’ public health campaign, the centenary-of-federation ads that taught generations who our first prime minister was, and Telstra’s promotion of unity in football under the motto ‘It’s the things that set us apart that bring us together."
#       │           ❌ AI 结论: 文本中提到的'Be'是'Life. Be in it.'宣传口号的一部分，与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [Be]
#       │           上下文: "Australia has a proud history of national campaigns that build shared identity: the ‘Life. Be in it.’ public health campaign, the centenary-of-federation ads that taught generations who our first prime minister was, and Telstra’s promotion of unity in football under the motto ‘It’s the things that set us apart that bring us together."
#       │           ❌ AI 结论: 文本中提到的'Be'是'Life. Be in it.'活动的一部分，与金属矿产无关。
#       │
# ==========================================================================================
# [7] 文档: Global Climate Agreements: Successes and Failures...
#    Link: https://www.cfr.org/backgrounder/paris-global-climate-change-agreements
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "For example, President Biden announced in 2021 that the United States will aim to cut emissions by 50 to 52 percent compared to 2005 levels by 2030, doubling former President Barack Obama’s commitment. The following year, the U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是'United States'的缩写，与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "For example, President Biden announced in 2021 that the United States will aim to cut emissions by 50 to 52 percent compared to 2005 levels by 2030, doubling former President Barack Obama’s commitment. The following year, the U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是'United States'的缩写，与'能源矿产'无关。
#       │
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "Since negotiating the Paris accord in 2015, many of the 195 countries that are party to the agreement have strengthened their climate commitments—to include pledges on curbing emissions and supporting countries in adapting to the effects of extreme weather—during the annual UN climate conferences known as the Conference of the Parties (COP). While experts note that clear progress has been made towards the clean energy transition, cutting current emissions has proven challenging for the world’s top emitters. The United States, for instance, could be poised to ramp up fossil fuel production linked to global warming under the Donald Trump administration, which has previously minimized the effects of climate change and has withdrawn twice from the Paris Agreement."
#       │           ✅ AI 结论: 根据上下文提到的清洁能源转型和化石燃料生产，这里的'energy'明确指代能源类别。
#       │           --------------------------------------------------
#       │           关键词: [oil]
#       │           上下文: "The United States and EU introduced aat COP26, which aims to slash 30 percent of methane emissions levels between 2020 and 2030. At COP28, oil companies announced they would cut their methane emissions from wells and drilling by more than 80 percent by the end of the decade. However, pledges to phase out fossil fuels were not renewed the following year at COP29."
#       │           ✅ AI 结论: 根据上下文，'oil' 明确指代能源领域中的化石燃料资源。
#       │           --------------------------------------------------
#       │           关键词: [coal]
#       │           上下文: "In recent years, climate diplomacy has occurred increasingly through minilateral groupings. The(G20), representing countries that are responsible for 80 percent of the world’s greenhouse gas pollution, has pledged to stop financing new coal-fired power plants abroad and agreed to triple renewable energy capacity by the end of this decade. However, G20 governments have thus far failed to set a deadline to phase out fossil fuels."
#       │           ✅ AI 结论: 根据上下文提到的'coal-fired power plants'（燃煤电厂）和'renewable energy capacity'（可再生能源容量），这里的'coal'明确指代能源领域中的煤炭资源。
#       │           --------------------------------------------------
#       │           关键词: [renewable energy]
#       │           上下文: "In recent years, climate diplomacy has occurred increasingly through minilateral groupings. The(G20), representing countries that are responsible for 80 percent of the world’s greenhouse gas pollution, has pledged to stop financing new coal-fired power plants abroad and agreed to triple renewable energy capacity by the end of this decade. However, G20 governments have thus far failed to set a deadline to phase out fossil fuels."
#       │           ✅ AI 结论: 根据上下文提到的'triple renewable energy capacity'，这里的'renewable energy'明确指代能源类别。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <传统能源>
#       │           --------------------------------------------------
#       │           关键词: [Oil]
#       │           上下文: "The United States and EU introduced aat COP26, which aims to slash 30 percent of methane emissions levels between 2020 and 2030. At COP28, oil companies announced they would cut their methane emissions from wells and drilling by more than 80 percent by the end of the decade. However, pledges to phase out fossil fuels were not renewed the following year at COP29."
#       │           ✅ AI 结论: 根据上下文，'Oil' 明确指代传统能源中的石油资源。
#       │           --------------------------------------------------
#       │           关键词: [Coal]
#       │           上下文: "In recent years, climate diplomacy has occurred increasingly through minilateral groupings. The(G20), representing countries that are responsible for 80 percent of the world’s greenhouse gas pollution, has pledged to stop financing new coal-fired power plants abroad and agreed to triple renewable energy capacity by the end of this decade. However, G20 governments have thus far failed to set a deadline to phase out fossil fuels."
#       │           ✅ AI 结论: 根据上下文提到的'coal-fired power plants'，这里的'Coal'明确指代传统能源。
#       │           --------------------------------------------------
#       │           关键词: [Fossil fuel]
#       │           上下文: "While experts note that clear progress has been made towards the clean energy transition, cutting current emissions has proven challenging for the world’s top emitters. The United States, for instance, could be poised to ramp up fossil fuel production linked to global warming under the Donald Trump administration, which has previously minimized the effects of climate change and has withdrawn twice from the Paris Agreement.. Though not intended to tackle climate change, the[PDF] was a historic environmental accord that became a model for future diplomacy on the issue."
#       │           ✅ AI 结论: 根据上下文，'Fossil fuel' 明确指代传统能源。
#       │       + 三级分类: <新能源>
#       │           --------------------------------------------------
#       │           关键词: [Renewable energy]
#       │           上下文: "In recent years, climate diplomacy has occurred increasingly through minilateral groupings. The(G20), representing countries that are responsible for 80 percent of the world’s greenhouse gas pollution, has pledged to stop financing new coal-fired power plants abroad and agreed to triple renewable energy capacity by the end of this decade. However, G20 governments have thus far failed to set a deadline to phase out fossil fuels."
#       │           ✅ AI 结论: 根据上下文提到的'triple renewable energy capacity'，这里的'Renewable energy'明确指代新能源。
#       │
# ==========================================================================================
# [8] 文档: Myanmar’s Troubled History...
#    Link: https://www.cfr.org/backgrounder/myanmar-history-coup-military-rule-ethnic-conflict-rohingya
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [mineral]
#       │           上下文: "Poverty has remained high in rural areas, where most people live. The country’s significant mineral deposits, particularly of jade and rubies, and natural gas reserves have drawn international attention. But some countries, including the United States, have sanctions on exports of many types of gems from Myanmar, because gems, natural gas, and other resources are often directly controlled by military-dominated firms or by firms close to the armed forces."
#       │           ✅ AI 结论: 根据后文提到的宝石和自然资源，这里的'mineral'指代矿产资源。
#       │           --------------------------------------------------
#       │           关键词: [mining]
#       │           上下文: "Tensions were exacerbated in 1962, when the military junta took over, curtailed ethnic minorities’ rights, and used scorched-earth tactics against some ethnic armed organizations. Some of the more recent fighting has centered around control of natural resources and of illegal activities including illicit gem mining and the drug trade.Before the 2021 coup, fighting primarily occurred in Myanmar’s[PDF]."
#       │           ✅ AI 结论: 根据上下文提到的'illicit gem mining'，这里的'mining'指代矿产开采活动。
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "By January 2022, analysts reported that clashes between the People’s Defense Force and the military were occurring in most of the country. “We’re seeing fighting now in townships that have not witnessed any form of fighting since Myanmar’s independence,” Jason Tower of the U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是人名Jason Tower的一部分，与矿产无关。
#       │           --------------------------------------------------
#       │           关键词: [nickel]
#       │           上下文: "Work on development projects has since resumed. But attacks have, with opposition forces disrupting a China-backed nickel plant in January, for example.At the same time, some of Myanmar’s top military leaders have, fearing that Nay Pyi Taw could fall too deeply into Beijing’s sphere of influence, according to the International Crisis Group."
#       │           ✅ AI 结论: 根据上下文提到的'nickel plant'，这里的'nickel'明确指代镍矿资源。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "By January 2022, analysts reported that clashes between the People’s Defense Force and the military were occurring in most of the country. “We’re seeing fighting now in townships that have not witnessed any form of fighting since Myanmar’s independence,” Jason Tower of the U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是人名Jason Tower的一部分，与能源矿产无关。
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [Nickel]
#       │           上下文: "Work on development projects has since resumed. But attacks have, with opposition forces disrupting a China-backed nickel plant in January, for example.At the same time, some of Myanmar’s top military leaders have, fearing that Nay Pyi Taw could fall too deeply into Beijing’s sphere of influence, according to the International Crisis Group."
#       │           ✅ AI 结论: 根据上下文提到的'nickel plant'，这里的'Nickel'明确指代金属矿产。
#       │
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "Some ASEAN members, such as Thailand, are close to the junta.China has funded infrastructure and energy projects throughout Myanmar as part of its. Oil and natural gas flow through pipelines from Myanmar to China."
#       │           ✅ AI 结论: 根据后文提到的能源项目和石油、天然气管道，这里的'energy'指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [oil]
#       │           上下文: "China has funded infrastructure and energy projects throughout Myanmar as part of its. Oil and natural gas flow through pipelines from Myanmar to China. Beijing is also working to create ain Rakhine State to connect China’s landlocked Yunnan Province to the Indian Ocean."
#       │           ✅ AI 结论: 根据上下文提到的石油和天然气输送管道，'oil' 明确指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [natural gas]
#       │           上下文: "Poverty has remained high in rural areas, where most people live. The country’s significant mineral deposits, particularly of jade and rubies, and natural gas reserves have drawn international attention. But some countries, including the United States, have sanctions on exports of many types of gems from Myanmar, because gems, natural gas, and other resources are often directly controlled by military-dominated firms or by firms close to the armed forces."
#       │           ✅ AI 结论: 根据文本中提到的'natural gas reserves'，这里的'natural gas'明确指代能源资源。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <传统能源>
#       │           --------------------------------------------------
#       │           关键词: [Oil]
#       │           上下文: "China has funded infrastructure and energy projects throughout Myanmar as part of its. Oil and natural gas flow through pipelines from Myanmar to China. Beijing is also working to create ain Rakhine State to connect China’s landlocked Yunnan Province to the Indian Ocean."
#       │           ✅ AI 结论: 根据上下文提到的'Oil and natural gas flow through pipelines from Myanmar to China'，这里的'Oil'明确指代传统能源。
#       │           --------------------------------------------------
#       │           关键词: [Natural Gas]
#       │           上下文: "Poverty has remained high in rural areas, where most people live. The country’s significant mineral deposits, particularly of jade and rubies, and natural gas reserves have drawn international attention. But some countries, including the United States, have sanctions on exports of many types of gems from Myanmar, because gems, natural gas, and other resources are often directly controlled by military-dominated firms or by firms close to the armed forces."
#       │           ✅ AI 结论: 根据上下文，'Natural Gas' 明确指代一种传统能源类型。
#       │
# ==========================================================================================
# [11] 文档: How Tobacco Laws Could Help Close the Racial Gap on Cancer...
#    Link: https://www.cfr.org/article/how-new-tobacco-control-laws-could-help-close-racial-gap-us-cancer
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "Tobacco use—theof preventable death in America—could be the issue on which the Biden administration comes closest to fulfilling that promise. This interactive examines how nationwide bans onand, as proposed by the Biden administration on April 28, 2022, could help shrink the racial gap on U.S."
#       │           ❌ AI 结论: 文本中提到的'U'没有明确指代矿产，且上下文与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "Tobacco use—theof preventable death in America—could be the issue on which the Biden administration comes closest to fulfilling that promise. This interactive examines how nationwide bans onand, as proposed by the Biden administration on April 28, 2022, could help shrink the racial gap on U.S."
#       │           ❌ AI 结论: 文本中提到的'U'未明确指代能源矿产，且上下文与能源矿产无关。
#       │
# ==========================================================================================
# [13] 文档: Is the UN Ready for Sweeping Reforms?...
#    Link: https://www.cfr.org/article/un80-initiative-what-know-about-united-nations-reform-plan
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: ")These growing arrears are worsened by funding cuts from powerful member states. In the United States, historically the, President Donald Trump has called for a review of all U.S."
#       │           ❌ AI 结论: 文本中提到的'U'未明确指代矿产，且上下文未涉及任何与矿产相关的描述。
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "”This institutional gridlock, coupled with rising tensions among the world’s major powers, has created an especially volatile environment for organizational reform. “The big problem for UN80 is that you can’t imagine a worse time to plan for major reforms than when [the presidents of China, Russia, and the United States] are in office, have vetoes, and are at each other’s throats,” said Michael W. Doyle, former assistant secretary-general and special advisor to UN Secretary-General Kofi Annan."
#       │           ❌ AI 结论: 文本中提到的'W'是人名Michael W. Doyle的一部分，而非指代矿产。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: ")These growing arrears are worsened by funding cuts from powerful member states. In the United States, historically the, President Donald Trump has called for a review of all U.S."
#       │           ❌ AI 结论: 文本中提到的'U'未明确指代能源矿产，且上下文未涉及相关资源或元素。
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "”This institutional gridlock, coupled with rising tensions among the world’s major powers, has created an especially volatile environment for organizational reform. “The big problem for UN80 is that you can’t imagine a worse time to plan for major reforms than when [the presidents of China, Russia, and the United States] are in office, have vetoes, and are at each other’s throats,” said Michael W. Doyle, former assistant secretary-general and special advisor to UN Secretary-General Kofi Annan."
#       │           ❌ AI 结论: 文本中提到的'W'是人名Michael W. Doyle的一部分，不属于金属矿产。
#       │
# ==========================================================================================
# [20] 文档: Trump says Xi approves of TikTok deal as leaders plan South ...
#    Link: https://www.bbc.com/news/articles/c4g7l7yl832o
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【稀土】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [rare earth]
#       │           上下文: "The call between Xi and Trump is the second so far this year. In June, the two leaders spoke to discuss China's export of rare earth minerals, resulting in China agreeing to approve a "certain number" of export permits to US companies, as well as the magnets made from them. Chinese and US officials have held four rounds of talks in recent months, and so far held off on implementing extremely high tariffs and strict export controls."
#       │           ✅ AI 结论: 根据上下文提到的'export of rare earth minerals'，这里的'reare earth'明确指代稀土资源。
#       │
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [minerals]
#       │           上下文: "The call between Xi and Trump is the second so far this year. In June, the two leaders spoke to discuss China's export of rare earth minerals, resulting in China agreeing to approve a "certain number" of export permits to US companies, as well as the magnets made from them. Chinese and US officials have held four rounds of talks in recent months, and so far held off on implementing extremely high tariffs and strict export controls."
#       │           ✅ AI 结论: 根据上下文提到的'Rare earth minerals'（稀土矿物）和'magnets made from them'（由其制成的磁铁），可以推断'minerals'在此处指代矿产资源。
#       │
# ==========================================================================================
# [24] 文档: How I Got My Career in Foreign Policy: John SawersPhoto coll...
#    Link: https://www.cfr.org/article/how-i-got-my-career-foreign-policy-john-sawers
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "And I saw it through the end of the P.W. Botha era, the opening up of politics on the minority white side, then the release of ANC [African National Congress] prisoners, ultimately the release of Nelson Mandela, then the difficulties and negotiations in 1990–1991."
#       │           ❌ AI 结论: 文本中未提及与矿产相关的任何内容，且'W'在此处不表示矿产。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "And I saw it through the end of the P.W. Botha era, the opening up of politics on the minority white side, then the release of ANC [African National Congress] prisoners, ultimately the release of Nelson Mandela, then the difficulties and negotiations in 1990–1991."
#       │           ❌ AI 结论: 文本中提到的'W'没有明确指代金属矿产，且上下文与政治历史相关，未涉及矿产资源。
#       │
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "Then you’ve got the overarching issues of technology—competition over technology, how it’s changing everybody’s lives. The issues of climate, of how climate change is going to drive large movements of people, as their territory becomes sort of infertile or inhospitable, going to create conflicts, and the energy transition is going to be another big driver of change in the global economy, just like technology is a big driver of change.So these overarching issues, I think, are also very important and relate to migration, which has become the single most toxic domestic policy issue in many of our countries."
#       │           ✅ AI 结论: 根据上下文提到的'energy transition'，这里的'energy'明确指代能源。
#       │
# ==========================================================================================
# [25] 文档: How I Got My Career in Foreign Policy: Farah Pandith...
#    Link: https://www.cfr.org/article/how-i-got-my-career-foreign-policy-farah-pandith
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "I want to do something important, that makes lives better.”Ivana, she opens up a piece of paper and spreads it on her desk—it’s an [organizational] chart of the U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是'U.S.'的缩写，指代美国，与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "I want to do something important, that makes lives better.”Ivana, she opens up a piece of paper and spreads it on her desk—it’s an [organizational] chart of the U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是'U.S.'的缩写，指代美国，与能源矿产无关。
#       │
# ==========================================================================================
# [26] 文档: How I Got My Career in Foreign Policy: Michelle Gavin...
#    Link: https://www.cfr.org/article/how-i-got-my-career-foreign-policy-michelle-gavin
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "So, I think that got my foot in the door.The Senate was a wonderful place to get a perspective on U.S."
#       │           ❌ AI 结论: 文本中'U'没有明确指代矿产，且上下文未涉及任何与矿产相关的内容。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "So, I think that got my foot in the door.The Senate was a wonderful place to get a perspective on U.S."
#       │           ❌ AI 结论: 文本中'U'未明确指代能源矿产，且上下文未涉及相关资源信息。
#       │
# ==========================================================================================
# [27] 文档: How Donald Trump has turned the White House into his Imperia...
#    Link: https://www.lowyinstitute.org/publications/how-donald-trump-has-turned-white-house-his-imperial-court
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [minerals]
#       │           上下文: "One country that hasn’t played the game is China itself. Trump took a step back from punishing the Chinese, after they delayed essential supplies of the critical minerals that they have a lock on. Thus far, Australia has quietly resisted as well, though Anthony Albanese will have to front up in Washington, or elsewhere in the US, at some stage."
#       │           ✅ AI 结论: 根据上下文提到的'critical minerals'（关键矿物）和'China has a lock on'（中国掌握），这里的'minerals'明确指代矿产资源。
#       │           --------------------------------------------------
#       │           关键词: [critical minerals]
#       │           上下文: "One country that hasn’t played the game is China itself. Trump took a step back from punishing the Chinese, after they delayed essential supplies of the critical minerals that they have a lock on. Thus far, Australia has quietly resisted as well, though Anthony Albanese will have to front up in Washington, or elsewhere in the US, at some stage."
#       │           ✅ AI 结论: 根据上下文提到的'critical minerals'被中国控制，且与供应链相关，可以推断其指代矿产资源。
#       │
# ==========================================================================================
# [32] 文档: The UN at Eighty: Multilateralism in Crisis...
#    Link: https://www.lowyinstitute.org/publications/un-eighty-multilateralism-crisis
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "Legal scholars warn of a “catastrophic collapse of norms against the use of force.” Meanwhile, U.S."
#       │           ❌ AI 结论: 文本中‘U’未明确指代矿产，且上下文与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "Legal scholars warn of a “catastrophic collapse of norms against the use of force.” Meanwhile, U.S."
#       │           ❌ AI 结论: 文本中'U'未明确指代能源矿产，且上下文与能源矿产无关。
#       │
# ==========================================================================================
# [34] 文档: Bougainville’s future: A roadmap for development...
#    Link: https://www.lowyinstitute.org/publications/bougainville-s-future-roadmap-development
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [mineral]
#       │           上下文: "The first phase, beginning in 1964, marked the origins of the relationship between the Australian territory of Papua and New Guinea and its Bougainville District (later Province). [6] Key events in this period included the confirmation of significant mineral deposits in Bougainville's Crown Prince Range by Conzinc Riotinto of Australia, and the first nationwide elections forming the basis of PNG’s legislature, the House of Assembly. [7] The Panguna copper mine in central Bougainville was opened in 1972, operating until its forced closure in 1989 by aggrieved landowners."
#       │           ✅ AI 结论: 根据上下文提到的'矿物储量'和'铜矿'，'mineral'在此处明确指代矿产资源。
#       │           --------------------------------------------------
#       │           关键词: [mining]
#       │           上下文: "[13] The conflict involved fighting between PNG security forces (primarily the PNG Defence Force) and Bougainville’s separatist groups, mainly the Bougainville Revolutionary Army. While the forced closure of the Panguna mine was a catalyst, the underlying causes of this conflict were complex and myriad, including disagreements over royalty payments for customary landowners, environmental damage caused by mining operations, and pre-existing tensions between Bougainvilleans and other Papua New Guinea ethnicities. [14] The effects of the conflict were devastating: an estimated 15,000 deaths, displacement of more than 70,000 civilians, [15] and the near-total destruction of the island's social and economic infrastructure."
#       │           ✅ AI 结论: 根据上下文提到的'Panguna mine'和'mining operations'，这里的'mining'明确指代矿产相关活动。
#       │           --------------------------------------------------
#       │           关键词: [copper]
#       │           上下文: "[6] Key events in this period included the confirmation of significant mineral deposits in Bougainville's Crown Prince Range by Conzinc Riotinto of Australia, and the first nationwide elections forming the basis of PNG’s legislature, the House of Assembly. [7] The Panguna copper mine in central Bougainville was opened in 1972, operating until its forced closure in 1989 by aggrieved landowners. The mine operators’ lack of consideration for local concerns, [8] and the fact that Bougainville only had four seats in the PNG House of Assembly, signalled to Bougainville leaders that, to determine their own destiny, moves towards independence had to be made before PNG obtained its independence."
#       │           ✅ AI 结论: 根据文本中提到的'Panguna copper mine'，可以判断'copper'指代铜矿，属于矿产类别。
#       │
# ==========================================================================================
# [40] 文档: Trolls mock me for having fewer viewers, Fortnite streamer N...
#    Link: https://www.bbc.com/news/articles/cvg98zd9q75o
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "Ninja particularly wants to encourage younger people to get their moles checked out and hopes that the stream will target his and younger generations. He says he'll be live for 12 hours of the livestream as he no longer has the energy for longer marathon sessions in front of the webcam. "I'm 34 - I need my sleep man!"
#       │           ❌ AI 结论: 根据上下文，'energy' 指的是体力或精力，而不是能源资源。
#       │
# ==========================================================================================
# [46] 文档: The Fed’s Path to Year’s First Interest Rate Cut...
#    Link: https://www.cfr.org/backgrounder/what-us-federal-reserve
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "The Fed’s Path to Year’s First Interest Rate Cut The U.S."
#       │           ❌ AI 结论: 文本片段中关键词'U'未明确指代矿产，且语境与矿产无关。
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "–. Appointed by President George W. Bush, Bernanke’s two terms spanned the worst years of the, known as the Great Recession."
#       │           ❌ AI 结论: 文本中'W'是人名George W. Bush的一部分，与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "The Fed’s Path to Year’s First Interest Rate Cut The U.S."
#       │           ❌ AI 结论: 文本片段中'U'未明确指代能源矿产，且上下文与能源矿产无关。
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "–. Appointed by President George W. Bush, Bernanke’s two terms spanned the worst years of the, known as the Great Recession."
#       │           ❌ AI 结论: 文本中'W'是人名George W. Bush的一部分，与金属矿产无关。
#       │
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "With an aggressive Fed response and unprecedented fiscal stimulus, the economic recovery was much faster than the one following the Great Recession. However, the stimulus—in conjunction with depressed demand from lockdowns,, and high global energy prices following—contributed to the highest inflation rate since the early 1980s. This inflationary environment led the Fed to use interest rate hikes to try to cool off the economy while avoiding a recession—a goal known as a “soft landing."
#       │           ✅ AI 结论: 根据上下文提到的'high global energy prices'，这里的'energy'明确指代能源。
#       │
# ==========================================================================================
# [51] 文档: Director-General announces appointment of new Chief Economis...
#    Link: https://www.wto.org/english/news_e/news25_e/rese_17sep25_e.htm
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "Director-General announces appointment of new Chief Economist "I am delighted to announce the appointment of Professor Robert W. Staiger to the position of Chief Economist and Director, ERSD," the Director-General said."
#       │           ❌ AI 结论: 文本中'W'是人名Robert W. Staiger的一部分，不属于矿产。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "Director-General announces appointment of new Chief Economist "I am delighted to announce the appointment of Professor Robert W. Staiger to the position of Chief Economist and Director, ERSD," the Director-General said."
#       │           ❌ AI 结论: 文本中'W'是人名Robert W. Staiger的一部分，与金属矿产无关。
#       │
# ==========================================================================================
# [56] 文档: DG Okonjo-Iweala stresses important role of partnerships to ...
#    Link: https://www.wto.org/english/news_e/news25_e/infac_16sep25_e.htm
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【稀土】
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <重稀土>
#       │           --------------------------------------------------
#       │           关键词: [Y]
#       │           上下文: "Special guests included Jochen Wermuth, Managing Director of Wermuth Asset Management, and Eng. Adeeb Y. Al Aama, CEO of the Islamic Trade Finance Corporation, alongside other senior representatives."
#       │           ❌ AI 结论: 文本中'Y'是人名'Adeeb Y. Al Aama'的一部分，与'重稀土'无关。
#       │
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [Co]
#       │           上下文: "DG Okonjo-Iweala stresses important role of partnerships to boost opportunities for LDCs Co-organized by The Gambia (Coordinator of the WTO LDC Group), Germany (EIF Funding Partner Coordinator) and the Executive Secretariat of the EIF, the event was held as part of the EIF Global Forum 2025 entitled "Accelerating Impact – On the Road to EIF Phase Three". Building on a recent side event at the 4th International Conference on Financing for Development in Sevilla in June, this meeting marked another critical step towards the launch of EIF Phase Three."
#       │           ❌ AI 结论: 文本中未提及与矿产相关的内容，'Co' 在此为普通单词，未指代矿产资源。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [Co]
#       │           上下文: "DG Okonjo-Iweala stresses important role of partnerships to boost opportunities for LDCs Co-organized by The Gambia (Coordinator of the WTO LDC Group), Germany (EIF Funding Partner Coordinator) and the Executive Secretariat of the EIF, the event was held as part of the EIF Global Forum 2025 entitled "Accelerating Impact – On the Road to EIF Phase Three". Building on a recent side event at the 4th International Conference on Financing for Development in Sevilla in June, this meeting marked another critical step towards the launch of EIF Phase Three."
#       │           ❌ AI 结论: 文本中未提及与金属矿产相关的内容，'Co' 在此语境中不指代金属矿产。
#       │
# ==========================================================================================
# [58] 文档: The Importance of Fed Independence...
#    Link: https://www.cfr.org/expert-brief/importance-fed-independence
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "In the first decades following its founding in 1913, the executive branch (particularly the Treasury Department) maintained significant control over monetary policy. The Fed did not secure true operational independence from the federal government until the, which allowed it to set monetary policy without concern for the long-term borrowing costs of the U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是美国（U.S.）的缩写，与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "In the first decades following its founding in 1913, the executive branch (particularly the Treasury Department) maintained significant control over monetary policy. The Fed did not secure true operational independence from the federal government until the, which allowed it to set monetary policy without concern for the long-term borrowing costs of the U.S."
#       │           ❌ AI 结论: 文本中'U'未明确指代能源矿产，且上下文与能源矿产无关。
#       │
# ==========================================================================================
# [64] 文档: How U.S. Trade Policy Has Shaken Allies...
#    Link: https://www.cfr.org/article/geopolitics-trump-tariffs-how-us-trade-policy-has-shaken-allies
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "How U.S."
#       │           ❌ AI 结论: 文本片段中'U'未明确指代矿产，且上下文不完整，无法判断其具体含义。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "How U.S."
#       │           ❌ AI 结论: 文本片段中'U'仅为字母，未明确指代能源矿产。
#       │
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "Yet the Turnberry deal might prove to be the beginning of Europe’s strategic awakening. In the short term, it does entrench Europe’s dependence on the United States—especially in energy and defense—but this forced dependence is also setting in motion countervailing dynamics that will reshape Europe’s geopolitical posture in three critical areas in the medium and long term.Brussels is accelerating trade talks with Canada, Japan, and South Korea, while the free trade agreement with—the South American trade bloc consisting of Argentina, Bolivia, Brazil, Paraguay, and Uruguay—would lead to the largest free trading area in the world, with the ratification process now officially underway."
#       │           ✅ AI 结论: 根据上下文提到的'energy and defense'，这里的'energy'明确指代能源领域。
#       │           --------------------------------------------------
#       │           关键词: [natural gas]
#       │           上下文: "S. liquid natural gas locks in short-term dependence, the political lesson has been internalized: Europe cannot afford to swap reliance on Russian pipelines for reliance on U.S."
#       │           ✅ AI 结论: 根据上下文，'natural gas' 明确指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [renewable energy]
#       │           上下文: "tankers. The logical response will be a doubling down on renewable energy.Early signs from the second Trump administrationfor even the most supportive U."
#       │           ✅ AI 结论: 根据上下文提到的'renewable energy'，明确指代能源领域。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <传统能源>
#       │           --------------------------------------------------
#       │           关键词: [Natural Gas]
#       │           上下文: "S. liquid natural gas locks in short-term dependence, the political lesson has been internalized: Europe cannot afford to swap reliance on Russian pipelines for reliance on U.S."
#       │           ✅ AI 结论: 根据上下文，'Natural Gas' 明确指代一种传统能源。
#       │       + 三级分类: <新能源>
#       │           --------------------------------------------------
#       │           关键词: [Renewable energy]
#       │           上下文: "tankers. The logical response will be a doubling down on renewable energy.Early signs from the second Trump administrationfor even the most supportive U."
#       │           ✅ AI 结论: 根据上下文中的' renewable energy'与'新能源'的语义一致，且未出现其他歧义解释。
#       │
# ==========================================================================================
# [65] 文档: Why the Supreme Court Must Rule Against Trump’s Tariffs...
#    Link: https://www.cfr.org/expert-brief/why-supreme-court-must-rule-against-trumps-tariffs
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "Why the Supreme Court Must Rule Against Trump’s Tariffs The U.S."
#       │           ❌ AI 结论: 文本片段中'U'未明确指代矿产，且语境与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "Why the Supreme Court Must Rule Against Trump’s Tariffs The U.S."
#       │           ❌ AI 结论: 文本中'U'未明确指代能源矿产，且上下文与能源矿产无关。
#       │
# ==========================================================================================
# [66] 文档: White House Tariff Policy Alienates Australia and New Zealan...
#    Link: https://www.cfr.org/expert-brief/trump-tariffs-australia-and-new-zealand-risk-us-pacific-strategy
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "White House Tariff Policy Alienates Australia and New Zealand Australia and—to a lesser extent—New Zealand are central to U.S."
#       │           ❌ AI 结论: 文本中'U'未明确指代矿产，且上下文未涉及矿产相关内容。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "White House Tariff Policy Alienates Australia and New Zealand Australia and—to a lesser extent—New Zealand are central to U.S."
#       │           ❌ AI 结论: 文本中'U'未明确指代能源矿产，且上下文与能源矿产无关。
#       │
# ==========================================================================================
# [67] 文档: Canada Lays the Groundwork to Pivot Away From the United Sta...
#    Link: https://www.cfr.org/expert-brief/canada-lays-groundwork-pivot-away-united-states
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "Canada Lays the Groundwork to Pivot Away From the United States For the past seventy-five years, the United States and Canada have pursued ever closer, celebrated “the world’s longest undefended border,” and built a friendship that was among the deepest between any two countries in the world. That all ended on March 26, 2025, when U.S."
#       │           ❌ AI 结论: 文本中提到的'U'未明确指代矿产，且上下文未涉及与矿产相关的内容。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "Canada Lays the Groundwork to Pivot Away From the United States For the past seventy-five years, the United States and Canada have pursued ever closer, celebrated “the world’s longest undefended border,” and built a friendship that was among the deepest between any two countries in the world. That all ended on March 26, 2025, when U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是作为人名或地名的一部分出现，未指代能源矿产。
#       │
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [oil]
#       │           上下文: "The Trans-Canada Highway is still a two-lane road in much of the country. Meanwhile, pipelines move most of Alberta’s oil, its most valuable commodity, south to Gulf Coast refineries rather than east to Ontario and Quebec or west to British Columbia and markets in Asia. Carney has promised towith the rest of the world by expanding ports, building liquefied natural gas terminals, and opening access to new resources for export."
#       │           ✅ AI 结论: 根据上下文，'oil' 明确指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [natural gas]
# ...
#       │           --------------------------------------------------
#       │           关键词: [oil]
#       │           上下文: "The electric car revolution is on track, says IEA Global electric vehicle sales are set to rise by more than a fifth to reach 17 million this year, powered by drivers in China, according to the International Energy Agency.In a report Tuesday, the IEA projected that “surging demand” for EVs over the next decade was set “to remake the global auto industry and significantly reduce oil consumption for road transport.”It expects half of all cars sold globally to be electric by 2035, up from more than one in five this year, provided charging infrastructure keeps pace."
#       │           ✅ AI 结论: 根据文本中提到的‘oil consumption for road transport’，这里的‘oil’明确指代能源资源。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <传统能源>
#       │           --------------------------------------------------
#       │           关键词: [Oil]
#       │           上下文: "The electric car revolution is on track, says IEA Global electric vehicle sales are set to rise by more than a fifth to reach 17 million this year, powered by drivers in China, according to the International Energy Agency.In a report Tuesday, the IEA projected that “surging demand” for EVs over the next decade was set “to remake the global auto industry and significantly reduce oil consumption for road transport.”It expects half of all cars sold globally to be electric by 2035, up from more than one in five this year, provided charging infrastructure keeps pace."
#       │           ✅ AI 结论: 根据上下文提到的‘oil consumption for road transport’，这里的‘Oil’明确指代传统能源。
#       │
# ==========================================================================================
# [488] 文档: What are stablecoins? Everything to know about the crypto be...
#    Link: https://www.cnn.com/2025/06/05/business/stablecoins-crypto-genius-act
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "There are also security risks like people forgetting the pass-code to their crypto wallet.The GENIUS act stands for “Guiding and Establishing National Innovation for U.S."
#       │           ❌ AI 结论: 文本中提到的'U'是'United States'的缩写，与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <能源矿产>
#       │           --------------------------------------------------
#       │           关键词: [U]
#       │           上下文: "There are also security risks like people forgetting the pass-code to their crypto wallet.The GENIUS act stands for “Guiding and Establishing National Innovation for U.S."
#       │           ❌ AI 结论: 文本中提到的'U'未明确指代能源矿产，且上下文与能源矿产无关。
#       │
# ==========================================================================================
# [489] 文档: How American consumers are feeling the squeeze, in 4 charts...
#    Link: https://www.cnn.com/2025/06/01/economy/consumer-student-loans-debt-squeeze-dg
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [oil]
#       │           上下文: "Consumer sentiment, and in May, according to the University of Michigan’s closely watched indicator of how people are feeling about the economy.Since 1952, when the university started tracking how Americans felt about the economy, there have been nearly a dozen recessions, several oil price shocks, a few wars, a couple of inflationary episodes, a major financial crisis and a global pandemic.Turns out, a massive trade war nearly trumps all."
#       │           ✅ AI 结论: 根据上下文提到的'oil price shocks'，这里的'oil'明确指代能源相关的内容。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <传统能源>
#       │           --------------------------------------------------
#       │           关键词: [Oil]
#       │           上下文: "Consumer sentiment, and in May, according to the University of Michigan’s closely watched indicator of how people are feeling about the economy.Since 1952, when the university started tracking how Americans felt about the economy, there have been nearly a dozen recessions, several oil price shocks, a few wars, a couple of inflationary episodes, a major financial crisis and a global pandemic.Turns out, a massive trade war nearly trumps all."
#       │           ✅ AI 结论: 根据上下文提到的'oil price shocks'，这里的'Oil'明确指代传统能源。
#       │
# ==========================================================================================
# [492] 文档: Five takeaways from Trump’s UN speech...
#    Link: https://www.cnn.com/2025/09/23/politics/takeaways-trump-un-speech
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "...ript and questioned the UN’s ability to solve problems much bigger than malfunctioning audio-visual equipment.Trump used the yearly foreign policy address to castigate foreign allies for supposedly ruining their countries with unchecked migration, fueling foreign conflicts with purchases of Russian energy, and ignoring his own peacemaking efforts.He addressed the most pressing foreign conflicts — the wars in Ukraine and Gaza — only in passing, instead reserving most of his speech to bemoan efforts to combat climate change, tout his own approach to world issues and take swipes at his predecessor (he ..."
#       │           ✅ AI 结论: 根据上下文提到的'purchases of Russian energy'，这里的'energy'明确指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [oil]
#       │           上下文: "Otherwise, we’re all wasting a lot of time.”European nations have dramatically reduced their oil purchases from Russia since its invasion of Ukraine, but continue to purchase natural gas. Two countries, Hungary and Slovakia, make up the bulk of European purchases of Russian oil."
#       │           ✅ AI 结论: 根据上下文提到的欧洲国家减少对俄罗斯的石油采购，这里的'oil'明确指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [natural gas]
#       │           上下文: "Otherwise, we’re all wasting a lot of time.”European nations have dramatically reduced their oil purchases from Russia since its invasion of Ukraine, but continue to purchase natural gas. Two countries, Hungary and Slovakia, make up the bulk of European purchases of Russian oil."
#       │           ✅ AI 结论: 根据上下文，'natural gas' 属于能源类别。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <传统能源>
#       │           --------------------------------------------------
#       │           关键词: [Oil]
#       │           上下文: "Otherwise, we’re all wasting a lot of time.”European nations have dramatically reduced their oil purchases from Russia since its invasion of Ukraine, but continue to purchase natural gas. Two countries, Hungary and Slovakia, make up the bulk of European purchases of Russian oil."
#       │           ✅ AI 结论: 根据上下文提到的俄罗斯石油采购，这里的'Oil'指代传统能源。
#       │           --------------------------------------------------
#       │           关键词: [Natural Gas]
#       │           上下文: "Otherwise, we’re all wasting a lot of time.”European nations have dramatically reduced their oil purchases from Russia since its invasion of Ukraine, but continue to purchase natural gas. Two countries, Hungary and Slovakia, make up the bulk of European purchases of Russian oil."
#       │           ✅ AI 结论: 根据上下文，Natural Gas（天然气）属于传统能源类别。
#       │           --------------------------------------------------
#       │           关键词: [Fossil fuel]
#       │           上下文: "Climate change, he said, was “the greatest con job ever perpetrated on the world.”The vast majority of climate scientists have, and that it is mainly caused by fossil fuel pollution. Already, the world is seeing its effects: Floods are becoming more extreme and deadly, droughts are more widespread and severe, and heat waves are more dangerous."
#       │           ✅ AI 结论: 根据上下文，'fossil fuel' 明确指代传统能源。
#       │
# ==========================================================================================
# [493] 文档: How the Roberts Court became the Trump Court...
#    Link: https://www.cnn.com/2025/09/24/politics/john-roberts-20-years-legacy-trump
#    [中国相关]: 否
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【矿产】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "”In his first decade, after his September 2005, Roberts’ opinions on intensely fought social dilemmas stood out.The appointee of President George W. Bush voted against school integration plans, university affirmative action, and a."
#       │           ❌ AI 结论: 文本中提到的'W'是George W. Bush名字的一部分，与矿产无关。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <金属矿产>
#       │           --------------------------------------------------
#       │           关键词: [W]
#       │           上下文: "”In his first decade, after his September 2005, Roberts’ opinions on intensely fought social dilemmas stood out.The appointee of President George W. Bush voted against school integration plans, university affirmative action, and a."
#       │           ❌ AI 结论: 关键词 'W' 是人名 'George W. Bush' 的一部分，与 '金属矿产' 无关。
#       │
# ==========================================================================================
# [494] 文档: • For Subscribers For Subscribers Mike Segar/Reuters...
#    Link: https://www.cnn.com/2025/09/24/politics/trump-un-speech-united-nations-analysis
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "After laying on afor the US president last week, the British delegation had to sit and watch him tell a lie — that London wants to go to sharia law. And Trump paid backobsequiousness by slamming his renewable energy policies. “Oh, the North Sea, I know it so well,” Trump said."
#       │           ✅ AI 结论: 根据上下文提到的'renewable energy policies'，这里的'energy'明确指代能源类别。
#       │           --------------------------------------------------
#       │           关键词: [oil]
#       │           上下文: "“Oh, the North Sea, I know it so well,” Trump said. “Three days in a row, that’s all he heard, North Sea oil, North Sea.” Starmer is already facing pressure from his own Labour MPs to condemn the man he hosted last week."
#       │           ✅ AI 结论: 根据上下文提到的'North Sea oil'，这里的'oil'明确指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [renewable energy]
#       │           上下文: "After laying on afor the US president last week, the British delegation had to sit and watch him tell a lie — that London wants to go to sharia law. And Trump paid backobsequiousness by slamming his renewable energy policies. “Oh, the North Sea, I know it so well,” Trump said."
#       │           ✅ AI 结论: 根据上下文，'renewable energy' 明确指代可再生能源，属于 '能源' 的范畴。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <传统能源>
#       │           --------------------------------------------------
#       │           关键词: [Oil]
#       │           上下文: "“Oh, the North Sea, I know it so well,” Trump said. “Three days in a row, that’s all he heard, North Sea oil, North Sea.” Starmer is already facing pressure from his own Labour MPs to condemn the man he hosted last week."
#       │           ✅ AI 结论: 根据上下文，'Oil' 明确指代传统能源中的石油资源。
#       │       + 三级分类: <新能源>
#       │           --------------------------------------------------
#       │           关键词: [Renewable energy]
#       │           上下文: "After laying on afor the US president last week, the British delegation had to sit and watch him tell a lie — that London wants to go to sharia law. And Trump paid backobsequiousness by slamming his renewable energy policies. “Oh, the North Sea, I know it so well,” Trump said."
#       │           ✅ AI 结论: 根据上下文，'renewable energy' 明确指代新能源相关的内容。
#       │
# ==========================================================================================
# [495] 文档: Trump’s ‘your countries are going to hell’ speech, annotated...
#    Link: https://www.cnn.com/2025/09/23/politics/united-nations-trump-speech-annotated
#    [中国相关]: 是
#    ★ 一级标签: 【战略资源】
#       ├── 二级标签: 【能源】
#       │     [原有关键词匹配 (Base) & AI 分析]:
#       │           --------------------------------------------------
#       │           关键词: [energy]
#       │           上下文: "Just release the hostages now.,: Even NATO countries have not cut off much Russian energy and Russian energy products, which, as you know, I found out about two weeks ago and I wasn’t happy. Think of it — they’re funding the war against themselves."
#       │           ✅ AI 结论: 根据上下文提到的'Russian energy'，这里的'energy'明确指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [coal]
#       │           上下文: ": The entire globalist concept of asking successful industrialized nations to inflict pain on themselves and radically disrupt their entire societies must be rejected completely and totally, and it must be immediate.: I have a little standing order in the White House — never use the word “coal,” only use the words, “clean, beautiful coal.” It sounds much better, doesn’t it?"
#       │           ✅ AI 结论: 根据上下文提到的‘clean, beautiful coal’，这里的‘coal’明确指代能源资源。
#       │           --------------------------------------------------
#       │           关键词: [Renewables]
#       │           上下文: "We have no choice.: We’re getting rid of the falsely named renewables. By the way, they’re a joke."
#       │           ✅ AI 结论: 根据上下文提到的'falsely named renewables'，可以推断'Renewables'在此处指代可再生能源，属于'能源'分类。
#       │           --------------------------------------------------
#       │           关键词: [renewable energy]
#       │           上下文: "” It sounds much better, doesn’t it?: In closing, I just want to repeat that immigration and the high cost of so-called green renewable energy is destroying a large part of the free world, and a large part of our planet. Countries that cherish freedom are fading fast because of their policies on these two subjects."
#       │           ✅ AI 结论: 根据上下文提到的'green renewable energy'，这里的'renewable energy'明确指代能源类别。
#       │     [新增三级标签匹配 (Detailed) & AI 分析]:
#       │       + 三级分类: <传统能源>
#       │           --------------------------------------------------
#       │           关键词: [Coal]
#       │           上下文: ": The entire globalist concept of asking successful industrialized nations to inflict pain on themselves and radically disrupt their entire societies must be rejected completely and totally, and it must be immediate.: I have a little standing order in the White House — never use the word “coal,” only use the words, “clean, beautiful coal.” It sounds much better, doesn’t it?"
#       │           ✅ AI 结论: 根据上下文，'Coal' 明确指代传统能源中的煤炭资源。
#       │       + 三级分类: <新能源>
#       │           --------------------------------------------------
#       │           关键词: [Renewables]
#       │           上下文: "We have no choice.: We’re getting rid of the falsely named renewables. By the way, they’re a joke."
#       │           ✅ AI 结论: 根据上下文中的'falsely named renewables'和语境判断，'Renewables'在此处指代新能源。
#       │           --------------------------------------------------
#       │           关键词: [Renewable energy]
#       │           上下文: "” It sounds much better, doesn’t it?: In closing, I just want to repeat that immigration and the high cost of so-called green renewable energy is destroying a large part of the free world, and a large part of our planet. Countries that cherish freedom are fading fast because of their policies on these two subjects."
#       │           ✅ AI 结论: 根据上下文提到的'green renewable energy'，这里的'Renewable energy'明确指代新能源。
#       │
# ==========================================================================================
#
# 测试结束。
# 共扫描文档: 500
# 命中【战略资源】相关文档: 127
